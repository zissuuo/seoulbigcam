# %%
import pandas as pd
import numpy as np

# %%
main = pd.read_csv('/Users/Jenny/Desktop/seoulbigcam/Final Data/14세까지의 인구 비율.csv')

# %%
main.rename(columns={'동별(1)': '구', '동별': '동', '~14세': '14세 이하 아동 수'}, inplace=True)
main
# Out:
#        구     동  14세 이하 아동 수   ~14세 비율
# 0     합계    소계     863015.0  0.091534
# 1    종로구    소계      10294.0  0.072811
# 2    종로구   사직동        848.0  0.093320
# 3    종로구   삼청동        142.0  0.060918
# 4    종로구   부암동        709.0  0.076723
# ..   ...   ...          ...       ...
# 447  강동구  암사1동       2900.0  0.085322
# 448  강동구  천호2동       2339.0  0.070448
# 449  강동구    길동       3349.0  0.074369
# 450  강동구  상일1동       7884.0  0.201967
# 451  강동구  상일2동       1525.0  0.128345
#
# [452 rows x 4 columns]

# %%
main = main[main['동'] != '소계']
main = main.reset_index(drop=True)
main
# Out:
#        구     동  14세 이하 아동 수   ~14세 비율
# 0    종로구   사직동        848.0  0.093320
# 1    종로구   삼청동        142.0  0.060918
# 2    종로구   부암동        709.0  0.076723
# 3    종로구   평창동       1743.0  0.098681
# 4    종로구   무악동        931.0  0.116041
# ..   ...   ...          ...       ...
# 421  강동구  암사1동       2900.0  0.085322
# 422  강동구  천호2동       2339.0  0.070448
# 423  강동구    길동       3349.0  0.074369
# 424  강동구  상일1동       7884.0  0.201967
# 425  강동구  상일2동       1525.0  0.128345
#
# [426 rows x 4 columns]

# %% [markdown]
# ### df1 ~ df5

# %%
df1 = pd.read_csv('/Users/Jenny/Desktop/seoulbigcam/Final Data/교육_국공립어린이집 비율_동별_2022.csv')

# %%
df1 = df1[df1['동'] != '일원2동']
df1
# Out:
#        구     동  전체  국공립  국공립 어린이집 비율
# 0    종로구   사직동  11    1     9.090909
# 1    종로구   삼청동   3    1    33.333333
# 2    종로구   부암동   3    2    66.666667
# 3    종로구   평창동   3    1    33.333333
# 4    종로구   무악동   3    3   100.000000
# ..   ...   ...  ..  ...          ...
# 422  강동구  암사1동  17    4    23.529412
# 423  강동구  천호2동  10    5    50.000000
# 424  강동구    길동  17    6    35.294118
# 425  강동구  상일1동  13    8    61.538462
# 426  강동구  상일2동  15    7    46.666667
#
# [426 rows x 5 columns]

# %%
df1.rename(columns={'전체': '전체 어린이집 수', '국공립': '국공립 어린이집 수'}, inplace=True)

# %%
main1 = pd.merge(main, df1, on = ['구', '동'], how = 'outer')
main1
# Out:
#        구     동  14세 이하 아동 수   ~14세 비율  전체 어린이집 수  국공립 어린이집 수  국공립 어린이집 비율
# 0    종로구   사직동        848.0  0.093320         11           1     9.090909
# 1    종로구   삼청동        142.0  0.060918          3           1    33.333333
# 2    종로구   부암동        709.0  0.076723          3           2    66.666667
# 3    종로구   평창동       1743.0  0.098681          3           1    33.333333
# 4    종로구   무악동        931.0  0.116041          3           3   100.000000
# ..   ...   ...          ...       ...        ...         ...          ...
# 421  강동구  암사1동       2900.0  0.085322         17           4    23.529412
# 422  강동구  천호2동       2339.0  0.070448         10           5    50.000000
# 423  강동구    길동       3349.0  0.074369         17           6    35.294118
# 424  강동구  상일1동       7884.0  0.201967         13           8    61.538462
# 425  강동구  상일2동       1525.0  0.128345         15           7    46.666667
#
# [426 rows x 7 columns]

# %%
df2 = pd.read_csv('/Users/Jenny/Desktop/seoulbigcam/Final Data/교육_국공립유치원 비율_동별_2023.csv')

# %%
df2.rename(columns={'합계': '전체 유치원 수', '공립 수': '국공립 유치원 수'}, inplace=True)

# %%
main2 = pd.merge(main1, df2, on = ['구', '동'], how = 'outer')
main2
# Out:
#        구     동  14세 이하 아동 수   ~14세 비율  전체 어린이집 수  국공립 어린이집 수  국공립 어린이집 비율  \
# 0    종로구   사직동        848.0  0.093320         11           1     9.090909
# 1    종로구   삼청동        142.0  0.060918          3           1    33.333333
# 2    종로구   부암동        709.0  0.076723          3           2    66.666667
# 3    종로구   평창동       1743.0  0.098681          3           1    33.333333
# 4    종로구   무악동        931.0  0.116041          3           3   100.000000
# ..   ...   ...          ...       ...        ...         ...          ...
# 421  강동구  암사1동       2900.0  0.085322         17           4    23.529412
# 422  강동구  천호2동       2339.0  0.070448         10           5    50.000000
# 423  강동구    길동       3349.0  0.074369         17           6    35.294118
# 424  강동구  상일1동       7884.0  0.201967         13           8    61.538462
# 425  강동구  상일2동       1525.0  0.128345         15           7    46.666667
#
#      전체 유치원 수  국공립 유치원 수  국공립 유치원 비율
# 0         1.0        0.0    0.000000
# ...

# %%
df3 = pd.read_csv('/Users/Jenny/Desktop/seoulbigcam/Final Data/교육_어린이집 교사 1인당 아동 수_구별_2022.csv')
df3.rename(columns={'아동 수': '어린이집 아동 수(구)', '교사 수': '어린이집 교사 수(구)', '교사 1인당 아동 수': '교사 1인당 아동 수(구)'}, inplace=True)

# %%
main3 = pd.merge(main2, df3, on = ['구'], how = 'left')
main3 = main3.rename(columns={'교사 1인당 아동 수(구)': '어린이집 교사 1인당 아동 수(구)'})
main3
# Out:
#        구     동  14세 이하 아동 수   ~14세 비율  전체 어린이집 수  국공립 어린이집 수  국공립 어린이집 비율  \
# 0    종로구   사직동        848.0  0.093320         11           1     9.090909
# 1    종로구   삼청동        142.0  0.060918          3           1    33.333333
# 2    종로구   부암동        709.0  0.076723          3           2    66.666667
# 3    종로구   평창동       1743.0  0.098681          3           1    33.333333
# 4    종로구   무악동        931.0  0.116041          3           3   100.000000
# ..   ...   ...          ...       ...        ...         ...          ...
# 421  강동구  암사1동       2900.0  0.085322         17           4    23.529412
# 422  강동구  천호2동       2339.0  0.070448         10           5    50.000000
# 423  강동구    길동       3349.0  0.074369         17           6    35.294118
# 424  강동구  상일1동       7884.0  0.201967         13           8    61.538462
# 425  강동구  상일2동       1525.0  0.128345         15           7    46.666667
#
#      전체 유치원 수  국공립 유치원 수  국공립 유치원 비율  어린이집 아동 수(구)  어린이집 교사 수(구)  \
# ...

# %%
df4 = pd.read_csv('/Users/Jenny/Desktop/seoulbigcam/Final Data/교육_유치원 교원 1인당 학생 수_구별_2022.csv')
df4.rename(columns={'학생 수': '유치원 학생 수(구)', '교원 수': '교원 수(구)', '교원 1인당 학생 수': '유치원 교원 1인당 학생 수(구)'}, inplace=True)

# %%
main4 = pd.merge(main3, df4, on = ['구'], how = 'left')
main4
# Out:
#        구     동  14세 이하 아동 수   ~14세 비율  전체 어린이집 수  국공립 어린이집 수  국공립 어린이집 비율  \
# 0    종로구   사직동        848.0  0.093320         11           1     9.090909
# 1    종로구   삼청동        142.0  0.060918          3           1    33.333333
# 2    종로구   부암동        709.0  0.076723          3           2    66.666667
# 3    종로구   평창동       1743.0  0.098681          3           1    33.333333
# 4    종로구   무악동        931.0  0.116041          3           3   100.000000
# ..   ...   ...          ...       ...        ...         ...          ...
# 421  강동구  암사1동       2900.0  0.085322         17           4    23.529412
# 422  강동구  천호2동       2339.0  0.070448         10           5    50.000000
# 423  강동구    길동       3349.0  0.074369         17           6    35.294118
# 424  강동구  상일1동       7884.0  0.201967         13           8    61.538462
# 425  강동구  상일2동       1525.0  0.128345         15           7    46.666667
#
#      전체 유치원 수  국공립 유치원 수  국공립 유치원 비율  어린이집 아동 수(구)  어린이집 교사 수(구)  \
# ...

# %%
df5 = pd.read_csv('/Users/Jenny/Desktop/seoulbigcam/Final Data/교육_지역아동센터_밀집도_동별_2023.csv')
df5 = df5.rename(columns={'센터 수': '아동센터 수'})

# %%
df5['동'] = df5['동'].str.replace('면목제3.8동', '면목3.8동')
# Out:
# /var/folders/x_/s6rt1hw118zdhq387czgy5q40000gn/T/ipykernel_11003/2393665642.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   df5['동'] = df5['동'].str.replace('면목제3.8동', '면목3.8동')

# %%
main5 = pd.merge(main4, df5, on = ['구', '동'], how = 'outer')
main5
# Out:
#        구     동  14세 이하 아동 수   ~14세 비율  전체 어린이집 수  국공립 어린이집 수  국공립 어린이집 비율  \
# 0    종로구   사직동        848.0  0.093320         11           1     9.090909
# 1    종로구   삼청동        142.0  0.060918          3           1    33.333333
# 2    종로구   부암동        709.0  0.076723          3           2    66.666667
# 3    종로구   평창동       1743.0  0.098681          3           1    33.333333
# 4    종로구   무악동        931.0  0.116041          3           3   100.000000
# ..   ...   ...          ...       ...        ...         ...          ...
# 421  강동구  암사1동       2900.0  0.085322         17           4    23.529412
# 422  강동구  천호2동       2339.0  0.070448         10           5    50.000000
# 423  강동구    길동       3349.0  0.074369         17           6    35.294118
# 424  강동구  상일1동       7884.0  0.201967         13           8    61.538462
# 425  강동구  상일2동       1525.0  0.128345         15           7    46.666667
#
#      전체 유치원 수  국공립 유치원 수  국공립 유치원 비율  어린이집 아동 수(구)  어린이집 교사 수(구)  \
# ...

# %% [markdown]
# ### df6 ~ df10

# %%
df6 = pd.read_csv('/Users/Jenny/Desktop/seoulbigcam/Final Data/교육_학교 수_동별_2023.csv')
df6
# Out:
#        구     동  학교 수
# 0    강남구  개포1동     3
# 1    강남구  개포2동     7
# 2    강남구  개포3동     7
# 3    강남구  개포4동     2
# 4    강남구  논현1동     1
# ..   ...   ...   ...
# 381  중랑구  상봉1동     2
# 382  중랑구  신내1동     3
# 383  중랑구  신내2동     2
# 384  중랑구  중화1동     8
# 385  하남시   감일동     1
#
# [386 rows x 3 columns]

# %%
df6['동'] = df6['동'].str.replace('면목제3.8동', '면목3.8동')
# Out:
# /var/folders/x_/s6rt1hw118zdhq387czgy5q40000gn/T/ipykernel_11003/901991324.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   df6['동'] = df6['동'].str.replace('면목제3.8동', '면목3.8동')

# %%
main6 = pd.merge(main5, df6, on = ['구', '동'], how = 'left')
main6
# Out:
#        구     동  14세 이하 아동 수   ~14세 비율  전체 어린이집 수  국공립 어린이집 수  국공립 어린이집 비율  \
# 0    종로구   사직동        848.0  0.093320         11           1     9.090909
# 1    종로구   삼청동        142.0  0.060918          3           1    33.333333
# 2    종로구   부암동        709.0  0.076723          3           2    66.666667
# 3    종로구   평창동       1743.0  0.098681          3           1    33.333333
# 4    종로구   무악동        931.0  0.116041          3           3   100.000000
# ..   ...   ...          ...       ...        ...         ...          ...
# 421  강동구  암사1동       2900.0  0.085322         17           4    23.529412
# 422  강동구  천호2동       2339.0  0.070448         10           5    50.000000
# 423  강동구    길동       3349.0  0.074369         17           6    35.294118
# 424  강동구  상일1동       7884.0  0.201967         13           8    61.538462
# 425  강동구  상일2동       1525.0  0.128345         15           7    46.666667
#
#      전체 유치원 수  국공립 유치원 수  국공립 유치원 비율  어린이집 아동 수(구)  어린이집 교사 수(구)  \
# ...

# %%
df7 = pd.read_csv('/Users/Jenny/Desktop/seoulbigcam/Final Data/교육_학원 수_동별_2023.csv')
df7 = df7.rename(columns={'학원명': '학원 수'})

# %%
main7 = pd.merge(main6, df7, on = ['구', '동'], how = 'outer')
main7 = main7.dropna(subset=['동'])
main7
# Out:
#        구     동  14세 이하 아동 수   ~14세 비율  전체 어린이집 수  국공립 어린이집 수  국공립 어린이집 비율  \
# 0    종로구   사직동        848.0  0.093320       11.0         1.0     9.090909
# 1    종로구   삼청동        142.0  0.060918        3.0         1.0    33.333333
# 2    종로구   부암동        709.0  0.076723        3.0         2.0    66.666667
# 3    종로구   평창동       1743.0  0.098681        3.0         1.0    33.333333
# 4    종로구   무악동        931.0  0.116041        3.0         3.0   100.000000
# ..   ...   ...          ...       ...        ...         ...          ...
# 421  강동구  암사1동       2900.0  0.085322       17.0         4.0    23.529412
# 422  강동구  천호2동       2339.0  0.070448       10.0         5.0    50.000000
# 423  강동구    길동       3349.0  0.074369       17.0         6.0    35.294118
# 424  강동구  상일1동       7884.0  0.201967       13.0         8.0    61.538462
# 425  강동구  상일2동       1525.0  0.128345       15.0         7.0    46.666667
#
#      전체 유치원 수  국공립 유치원 수  국공립 유치원 비율  ...  어린이집 교사 수(구)  어린이집 교사 1인당 아동 수(구)  \
# ...

# %%
df8 = pd.read_csv('/Users/Jenny/Desktop/seoulbigcam/Final Data/녹지현황.csv')
df8 = df8.rename(columns={'구별': '구', '개소 (개소)': '개소(구)', '면적 (㎡)': '녹지 면적 (㎡)(구)'})

# %%
main8 = pd.merge(main7, df8, on = '구', how = 'left')
main8
# Out:
#        구     동  14세 이하 아동 수   ~14세 비율  전체 어린이집 수  국공립 어린이집 수  국공립 어린이집 비율  \
# 0    종로구   사직동        848.0  0.093320       11.0         1.0     9.090909
# 1    종로구   삼청동        142.0  0.060918        3.0         1.0    33.333333
# 2    종로구   부암동        709.0  0.076723        3.0         2.0    66.666667
# 3    종로구   평창동       1743.0  0.098681        3.0         1.0    33.333333
# 4    종로구   무악동        931.0  0.116041        3.0         3.0   100.000000
# ..   ...   ...          ...       ...        ...         ...          ...
# 421  강동구  암사1동       2900.0  0.085322       17.0         4.0    23.529412
# 422  강동구  천호2동       2339.0  0.070448       10.0         5.0    50.000000
# 423  강동구    길동       3349.0  0.074369       17.0         6.0    35.294118
# 424  강동구  상일1동       7884.0  0.201967       13.0         8.0    61.538462
# 425  강동구  상일2동       1525.0  0.128345       15.0         7.0    46.666667
#
#      전체 유치원 수  국공립 유치원 수  국공립 유치원 비율  ...  유치원 학생 수(구)  교원 수(구)  \
# ...

# %%
df9 = pd.read_csv('/Users/Jenny/Desktop/seoulbigcam/Final Data/도시_근린시설(주요:집객시설) 밀집도_동별_2023.csv')
df9 = df9.rename(columns={'면적(km2)': '동 면적(km2)'})
df9['동'] = df9['동'].str.replace('면목제3.8동', '면목3.8동')
# Out:
# /var/folders/x_/s6rt1hw118zdhq387czgy5q40000gn/T/ipykernel_11003/2056618251.py:3: FutureWarning: The default value of regex will change from True to False in a future version.
#   df9['동'] = df9['동'].str.replace('면목제3.8동', '면목3.8동')

# %%
main9 = pd.merge(main8, df9, on = ['구', '동'], how = 'outer')
main9
# Out:
#        구     동  14세 이하 아동 수   ~14세 비율  전체 어린이집 수  국공립 어린이집 수  국공립 어린이집 비율  \
# 0    종로구   사직동        848.0  0.093320       11.0         1.0     9.090909
# 1    종로구   삼청동        142.0  0.060918        3.0         1.0    33.333333
# 2    종로구   부암동        709.0  0.076723        3.0         2.0    66.666667
# 3    종로구   평창동       1743.0  0.098681        3.0         1.0    33.333333
# 4    종로구   무악동        931.0  0.116041        3.0         3.0   100.000000
# ..   ...   ...          ...       ...        ...         ...          ...
# 421  강동구  암사1동       2900.0  0.085322       17.0         4.0    23.529412
# 422  강동구  천호2동       2339.0  0.070448       10.0         5.0    50.000000
# 423  강동구    길동       3349.0  0.074369       17.0         6.0    35.294118
# 424  강동구  상일1동       7884.0  0.201967       13.0         8.0    61.538462
# 425  강동구  상일2동       1525.0  0.128345       15.0         7.0    46.666667
#
#      전체 유치원 수  국공립 유치원 수  국공립 유치원 비율  ...  아동센터 수  면적(km2)  면적당 아동센터 수  학교 수  \
# ...

# %%
df10 = pd.read_csv('/Users/Jenny/Desktop/seoulbigcam/Final Data/도시_면적당 정류장 수_동별_2023.csv')

# %%
df10 = df10[['구', '동', '정류장 수', '면적당 정류장 수']]
df10['동'] = df10['동'].str.replace('면목제3.8동', '면목3.8동')
df10
# Out:
# /var/folders/x_/s6rt1hw118zdhq387czgy5q40000gn/T/ipykernel_11003/4082096802.py:2: FutureWarning: The default value of regex will change from True to False in a future version.
#   df10['동'] = df10['동'].str.replace('면목제3.8동', '면목3.8동')
#        구     동  정류장 수   면적당 정류장 수
# 0    강남구  개포1동     75   59.055118
# 1    강남구  개포2동    126   50.199203
# 2    강남구  개포3동     23   18.548387
# 3    강남구  개포4동     86   57.718121
# 4    강남구  논현1동    106   84.800000
# ..   ...   ...    ...         ...
# 421  중랑구  상봉2동     66  101.538462
# 422  중랑구  신내1동    232   90.625000
# 423  중랑구  신내2동    114  122.580645
# 424  중랑구  중화1동     44   68.750000
# 425  중랑구  중화2동     72   71.287129
#
# [426 rows x 4 columns]

# %%
main10 = pd.merge(main9, df10, on = ['구', '동'], how = 'outer')
main10
# Out:
#        구     동  14세 이하 아동 수   ~14세 비율  전체 어린이집 수  국공립 어린이집 수  국공립 어린이집 비율  \
# 0    종로구   사직동        848.0  0.093320       11.0         1.0     9.090909
# 1    종로구   삼청동        142.0  0.060918        3.0         1.0    33.333333
# 2    종로구   부암동        709.0  0.076723        3.0         2.0    66.666667
# 3    종로구   평창동       1743.0  0.098681        3.0         1.0    33.333333
# 4    종로구   무악동        931.0  0.116041        3.0         3.0   100.000000
# ..   ...   ...          ...       ...        ...         ...          ...
# 421  강동구  암사1동       2900.0  0.085322       17.0         4.0    23.529412
# 422  강동구  천호2동       2339.0  0.070448       10.0         5.0    50.000000
# 423  강동구    길동       3349.0  0.074369       17.0         6.0    35.294118
# 424  강동구  상일1동       7884.0  0.201967       13.0         8.0    61.538462
# 425  강동구  상일2동       1525.0  0.128345       15.0         7.0    46.666667
#
#      전체 유치원 수  국공립 유치원 수  국공립 유치원 비율  ...  면적당 아동센터 수  학교 수  학원 수  개소(구)  \
# ...

# %% [markdown]
# ### df11 ~ df15

# %%
df11 = pd.read_csv('/Users/Jenny/Desktop/seoulbigcam/Final Data/도시_면적당 지하철역 수_동별_2023.csv')

# %%
df11 = df11[['구', '동', '지하철역 수', '면적당 지하철역 수']]
df11['동'] = df11['동'].str.replace('면목제3.8동', '면목3.8동')
df11
# Out:
# /var/folders/x_/s6rt1hw118zdhq387czgy5q40000gn/T/ipykernel_11003/4068539765.py:2: FutureWarning: The default value of regex will change from True to False in a future version.
#   df11['동'] = df11['동'].str.replace('면목제3.8동', '면목3.8동')
#        구     동  지하철역 수  면적당 지하철역 수
# 0    강남구  개포2동       3    1.195219
# 1    강남구  논현1동       3    2.400000
# 2    강남구  논현2동       2    1.360544
# 3    강남구  대치1동       1    1.265823
# 4    강남구  대치2동       2    1.000000
# ..   ...   ...     ...         ...
# 203  중랑구   묵1동       1    0.833333
# 204  중랑구  상봉1동       1    1.136364
# 205  중랑구  상봉2동       1    1.538462
# 206  중랑구  신내1동       1    0.390625
# 207  중랑구  중화1동       1    1.562500
#
# [208 rows x 4 columns]

# %%
main11 = pd.merge(main10, df11, on = ['구', '동'], how = 'outer')
main11
# Out:
#        구     동  14세 이하 아동 수   ~14세 비율  전체 어린이집 수  국공립 어린이집 수  국공립 어린이집 비율  \
# 0    종로구   사직동        848.0  0.093320       11.0         1.0     9.090909
# 1    종로구   삼청동        142.0  0.060918        3.0         1.0    33.333333
# 2    종로구   부암동        709.0  0.076723        3.0         2.0    66.666667
# 3    종로구   평창동       1743.0  0.098681        3.0         1.0    33.333333
# 4    종로구   무악동        931.0  0.116041        3.0         3.0   100.000000
# ..   ...   ...          ...       ...        ...         ...          ...
# 421  강동구  암사1동       2900.0  0.085322       17.0         4.0    23.529412
# 422  강동구  천호2동       2339.0  0.070448       10.0         5.0    50.000000
# 423  강동구    길동       3349.0  0.074369       17.0         6.0    35.294118
# 424  강동구  상일1동       7884.0  0.201967       13.0         8.0    61.538462
# 425  강동구  상일2동       1525.0  0.128345       15.0         7.0    46.666667
#
#      전체 유치원 수  국공립 유치원 수  국공립 유치원 비율  ...  학원 수  개소(구)  녹지 면적 (㎡)(구)  근린시설 수  \
# ...

# %%
df12 = pd.read_csv('/Users/Jenny/Desktop/seoulbigcam/Final Data/사용년수별 공동주택_21년도 구별.csv')

# %%
df12 = df12.rename(columns={'자치구별': '구', '총계': '총 아파트 수'})
df12 = df12[df12['구'] != '소계']
df12
# Out:
#        구  총 아파트 수  5년 미만  5년 이상 10년 미만  10년 이상 15년 미만  15년 이상 20년 미만  \
# 1    종로구    14153   2762           167           2370           1425
# 2     중구    21729   2684          1220           4831           6013
# 3    용산구    36470   3871          1725           5840           4188
# 4    성동구    62937   5967         12232           3768           8719
# 5    광진구    32251   2635           762           4176           3077
# 6   동대문구    64609   6580          7119           7639          12679
# 7    중랑구    53258   4729          5621           2888           7828
# 8    성북구    79605  10010          3216          14759          28484
# 9    강북구    34130   1698           504           4823          12439
# 10   도봉구    65044    450          1293            507          11310
# 11   노원구   159693   3236          1079           1673          12207
# 12   은평구    58308  13823          3294          22503           6528
# 13  서대문구    49650   8508          9817           3522           4926
# ...

# %%
main12 = pd.merge(main11, df12, on = '구', how = 'outer')
main12
# Out:
#        구     동  14세 이하 아동 수   ~14세 비율  전체 어린이집 수  국공립 어린이집 수  국공립 어린이집 비율  \
# 0    종로구   사직동        848.0  0.093320       11.0         1.0     9.090909
# 1    종로구   삼청동        142.0  0.060918        3.0         1.0    33.333333
# 2    종로구   부암동        709.0  0.076723        3.0         2.0    66.666667
# 3    종로구   평창동       1743.0  0.098681        3.0         1.0    33.333333
# 4    종로구   무악동        931.0  0.116041        3.0         3.0   100.000000
# ..   ...   ...          ...       ...        ...         ...          ...
# 421  강동구  암사1동       2900.0  0.085322       17.0         4.0    23.529412
# 422  강동구  천호2동       2339.0  0.070448       10.0         5.0    50.000000
# 423  강동구    길동       3349.0  0.074369       17.0         6.0    35.294118
# 424  강동구  상일1동       7884.0  0.201967       13.0         8.0    61.538462
# 425  강동구  상일2동       1525.0  0.128345       15.0         7.0    46.666667
#
#      전체 유치원 수  국공립 유치원 수  국공립 유치원 비율  ...  5년 이상 10년 미만  10년 이상 15년 미만  \
# ...

# %%
df13 = pd.read_csv('/Users/Jenny/Desktop/seoulbigcam/Final Data/외국인주민 비율_2022 동별.csv')

# %%
df13.rename(columns={'구별': '구', '동별': '동'},inplace=True)
df13 = df13[df13['동'] != '소계']

# %%
main13 = pd.merge(main12, df13, on = ['구', '동'], how = 'outer')
main13
# Out:
#        구     동  14세 이하 아동 수   ~14세 비율  전체 어린이집 수  국공립 어린이집 수  국공립 어린이집 비율  \
# 0    종로구   사직동        848.0  0.093320       11.0         1.0     9.090909
# 1    종로구   삼청동        142.0  0.060918        3.0         1.0    33.333333
# 2    종로구   부암동        709.0  0.076723        3.0         2.0    66.666667
# 3    종로구   평창동       1743.0  0.098681        3.0         1.0    33.333333
# 4    종로구   무악동        931.0  0.116041        3.0         3.0   100.000000
# ..   ...   ...          ...       ...        ...         ...          ...
# 421  강동구  암사1동       2900.0  0.085322       17.0         4.0    23.529412
# 422  강동구  천호2동       2339.0  0.070448       10.0         5.0    50.000000
# 423  강동구    길동       3349.0  0.074369       17.0         6.0    35.294118
# 424  강동구  상일1동       7884.0  0.201967       13.0         8.0    61.538462
# 425  강동구  상일2동       1525.0  0.128345       15.0         7.0    46.666667
#
#      전체 유치원 수  국공립 유치원 수  국공립 유치원 비율  ...  20년 이상 30년 미만  30년 이상 40년 미만  \
# ...

# %%
df14 = pd.read_csv('/Users/Jenny/Desktop/seoulbigcam/Final Data/자치구별 5대 범죄 발생 수_22년 구별.csv')

# %%
df14.rename(columns={'자치구별': '구', '발생': '5대 범죄 발생 수'},inplace=True)

# %%
main14 = pd.merge(main13, df14, on = '구', how = 'left')
main14
# Out:
#        구     동  14세 이하 아동 수   ~14세 비율  전체 어린이집 수  국공립 어린이집 수  국공립 어린이집 비율  \
# 0    종로구   사직동        848.0  0.093320       11.0         1.0     9.090909
# 1    종로구   삼청동        142.0  0.060918        3.0         1.0    33.333333
# 2    종로구   부암동        709.0  0.076723        3.0         2.0    66.666667
# 3    종로구   평창동       1743.0  0.098681        3.0         1.0    33.333333
# 4    종로구   무악동        931.0  0.116041        3.0         3.0   100.000000
# ..   ...   ...          ...       ...        ...         ...          ...
# 421  강동구  암사1동       2900.0  0.085322       17.0         4.0    23.529412
# 422  강동구  천호2동       2339.0  0.070448       10.0         5.0    50.000000
# 423  강동구    길동       3349.0  0.074369       17.0         6.0    35.294118
# 424  강동구  상일1동       7884.0  0.201967       13.0         8.0    61.538462
# 425  강동구  상일2동       1525.0  0.128345       15.0         7.0    46.666667
#
#      전체 유치원 수  국공립 유치원 수  국공립 유치원 비율  ...  30년 이상 40년 미만  40년 이상 50년 미만  \
# ...

# %%
df15 = pd.read_csv('/Users/Jenny/Desktop/seoulbigcam/Final Data/자치구별 경찰서 수_22년 구별.csv')

# %%
df15 = df15[['자치구별', '경찰서 및 지구대', '경찰서 1개당 면적']]
df15 = df15.rename(columns={'자치구별': '구', '경찰서 및 지구대': '경찰서 및 지구대(구)', '경찰서 1개당 면적': '경찰서 1개당 면적(구)'})

# %%
main15 = pd.merge(main14, df15, on = '구', how = 'left')
main15
# Out:
#        구     동  14세 이하 아동 수   ~14세 비율  전체 어린이집 수  국공립 어린이집 수  국공립 어린이집 비율  \
# 0    종로구   사직동        848.0  0.093320       11.0         1.0     9.090909
# 1    종로구   삼청동        142.0  0.060918        3.0         1.0    33.333333
# 2    종로구   부암동        709.0  0.076723        3.0         2.0    66.666667
# 3    종로구   평창동       1743.0  0.098681        3.0         1.0    33.333333
# 4    종로구   무악동        931.0  0.116041        3.0         3.0   100.000000
# ..   ...   ...          ...       ...        ...         ...          ...
# 421  강동구  암사1동       2900.0  0.085322       17.0         4.0    23.529412
# 422  강동구  천호2동       2339.0  0.070448       10.0         5.0    50.000000
# 423  강동구    길동       3349.0  0.074369       17.0         6.0    35.294118
# 424  강동구  상일1동       7884.0  0.201967       13.0         8.0    61.538462
# 425  강동구  상일2동       1525.0  0.128345       15.0         7.0    46.666667
#
#      전체 유치원 수  국공립 유치원 수  국공립 유치원 비율  ...  50년 이상  20년 미만 아파트 비율  \
# ...

# %%
df16 = pd.read_csv('/Users/Jenny/Desktop/seoulbigcam/Final Data/자치구별 방범용 cctv 수_23년 누적 구별.csv')
#df17 = pd.read_csv('/Users/Jenny/Desktop/seoulbigcam/Final Data/자치구별_공공도서관.csv')
#df18 = pd.read_csv('/Users/Jenny/Desktop/seoulbigcam/Final Data/자치구별_공원.csv')
#df19 = pd.read_csv('/Users/Jenny/Desktop/seoulbigcam/Final Data/자치구별_문화시설.csv')
#df20 = pd.read_csv('/Users/Jenny/Desktop/seoulbigcam/Final Data/자치동별 의료기관 수 _17년 동별.csv')
#df21 = pd.read_csv('/Users/Jenny/Desktop/seoulbigcam/Final Data/주간인구지수_구별 2020.csv')
#df22 = pd.read_csv('/Users/Jenny/Desktop/seoulbigcam/Final Data/주택보급률_22년도 동별.csv')
#df23 = pd.read_csv('/Users/Jenny/Desktop/seoulbigcam/Final Data/주택종류별_2020동별.csv')
#df24 = pd.read_csv('/Users/Jenny/Desktop/seoulbigcam/Final Data/house_values.csv')
#df25 = pd.read_csv('/Users/Jenny/Desktop/seoulbigcam/Final Data/land_values.csv')
#df26 = pd.read_csv('/Users/Jenny/Desktop/seoulbigcam/Final Data/policy_proportion.csv')
#df27 = pd.read_csv('/Users/Jenny/Desktop/seoulbigcam/Final Data/policy.csv')

# %%
df16.rename(columns={'구분': '구', '총계': 'cctv 수(구)'}, inplace=True)
df16 = df16[['구', 'cctv 수(구)']]
df16
# Out:
#        구 cctv 수(구)
# 0    종로구     1,966
# 1    중 구     2,584
# 2    용산구     2,970
# 3    성동구     4,175
# 4    광진구     3,592
# 5   동대문구     2,759
# 6    중랑구     4,193
# 7    성북구     4,957
# 8    강북구     3,321
# 9    도봉구     2,385
# 10   노원구     2,626
# 11   은평구     4,653
# 12  서대문구     3,538
# 13   마포구     2,638
# 14   양천구     3,890
# 15   강서구     3,353
# 16   구로구     4,831
# 17   금천구     2,885
# 18  영등포구     4,660
# 19   동작구     2,690
# 20   관악구     5,642
# 21   서초구     4,995
# 22   강남구     7,243
# 23   송파구     3,253
# 24   강동구     3,192

# %%
main16 = pd.merge(main15, df16, on = '구', how = 'left')
main16
# Out:
#        구     동  14세 이하 아동 수   ~14세 비율  전체 어린이집 수  국공립 어린이집 수  국공립 어린이집 비율  \
# 0    종로구   사직동        848.0  0.093320       11.0         1.0     9.090909
# 1    종로구   삼청동        142.0  0.060918        3.0         1.0    33.333333
# 2    종로구   부암동        709.0  0.076723        3.0         2.0    66.666667
# 3    종로구   평창동       1743.0  0.098681        3.0         1.0    33.333333
# 4    종로구   무악동        931.0  0.116041        3.0         3.0   100.000000
# ..   ...   ...          ...       ...        ...         ...          ...
# 421  강동구  암사1동       2900.0  0.085322       17.0         4.0    23.529412
# 422  강동구  천호2동       2339.0  0.070448       10.0         5.0    50.000000
# 423  강동구    길동       3349.0  0.074369       17.0         6.0    35.294118
# 424  강동구  상일1동       7884.0  0.201967       13.0         8.0    61.538462
# 425  강동구  상일2동       1525.0  0.128345       15.0         7.0    46.666667
#
#      전체 유치원 수  국공립 유치원 수  국공립 유치원 비율  ...  20년 미만 아파트 비율  10년 미만 아파트 비율  \
# ...

# %%
df17 = pd.read_csv('/Users/Jenny/Desktop/seoulbigcam/Final Data/자치구별_공공도서관.csv')

# %%
df17 = df17.rename(columns={'구명': '구', '수': '공공도서관 수(구)'})

# %%
main17 = pd.merge(main16, df17, on = '구', how = 'left')
main17
# Out:
#        구     동  14세 이하 아동 수   ~14세 비율  전체 어린이집 수  국공립 어린이집 수  국공립 어린이집 비율  \
# 0    종로구   사직동        848.0  0.093320       11.0         1.0     9.090909
# 1    종로구   삼청동        142.0  0.060918        3.0         1.0    33.333333
# 2    종로구   부암동        709.0  0.076723        3.0         2.0    66.666667
# 3    종로구   평창동       1743.0  0.098681        3.0         1.0    33.333333
# 4    종로구   무악동        931.0  0.116041        3.0         3.0   100.000000
# ..   ...   ...          ...       ...        ...         ...          ...
# 421  강동구  암사1동       2900.0  0.085322       17.0         4.0    23.529412
# 422  강동구  천호2동       2339.0  0.070448       10.0         5.0    50.000000
# 423  강동구    길동       3349.0  0.074369       17.0         6.0    35.294118
# 424  강동구  상일1동       7884.0  0.201967       13.0         8.0    61.538462
# 425  강동구  상일2동       1525.0  0.128345       15.0         7.0    46.666667
#
#      전체 유치원 수  국공립 유치원 수  국공립 유치원 비율  ...  10년 미만 아파트 비율  30년 이상 아파트 비율  \
# ...

# %%
df18 = pd.read_csv('/Users/Jenny/Desktop/seoulbigcam/Final Data/자치구별_공원.csv')

# %%
df18 = df18.rename(columns={'자치구': '구', '수': '공원 수(구)'})

# %%
main18 = pd.merge(main17, df18, on = '구', how = 'left')
main18
# Out:
#        구     동  14세 이하 아동 수   ~14세 비율  전체 어린이집 수  국공립 어린이집 수  국공립 어린이집 비율  \
# 0    종로구   사직동        848.0  0.093320       11.0         1.0     9.090909
# 1    종로구   삼청동        142.0  0.060918        3.0         1.0    33.333333
# 2    종로구   부암동        709.0  0.076723        3.0         2.0    66.666667
# 3    종로구   평창동       1743.0  0.098681        3.0         1.0    33.333333
# 4    종로구   무악동        931.0  0.116041        3.0         3.0   100.000000
# ..   ...   ...          ...       ...        ...         ...          ...
# 421  강동구  암사1동       2900.0  0.085322       17.0         4.0    23.529412
# 422  강동구  천호2동       2339.0  0.070448       10.0         5.0    50.000000
# 423  강동구    길동       3349.0  0.074369       17.0         6.0    35.294118
# 424  강동구  상일1동       7884.0  0.201967       13.0         8.0    61.538462
# 425  강동구  상일2동       1525.0  0.128345       15.0         7.0    46.666667
#
#      전체 유치원 수  국공립 유치원 수  국공립 유치원 비율  ...  30년 이상 아파트 비율     합계  외국인  외국인 비율  \
# ...

# %%
df19 = pd.read_csv('/Users/Jenny/Desktop/seoulbigcam/Final Data/자치구별_문화시설.csv')

df19 = df19.rename(columns={'자치구': '구', '수': '문화시설 수(구)'})
main19 = pd.merge(main18, df19, on = '구', how = 'left')
main19

# %%
df20 = pd.read_csv('/Users/Jenny/Desktop/seoulbigcam/Final Data/자치동별 의료기관 수 _17년 동별.csv')

# %%
df20['동'] = df20['동'].str.replace('일원2동', '개포3동')

# %%
main20 = pd.merge(main19, df20, on = ['구', '동'], how = 'outer')
main20
# Out:
#        구     동  14세 이하 아동 수   ~14세 비율  전체 어린이집 수  국공립 어린이집 수  국공립 어린이집 비율  \
# 0    종로구   사직동        848.0  0.093320       11.0         1.0     9.090909
# 1    종로구   삼청동        142.0  0.060918        3.0         1.0    33.333333
# 2    종로구   부암동        709.0  0.076723        3.0         2.0    66.666667
# 3    종로구   평창동       1743.0  0.098681        3.0         1.0    33.333333
# 4    종로구   무악동        931.0  0.116041        3.0         3.0   100.000000
# ..   ...   ...          ...       ...        ...         ...          ...
# 422  강동구  천호2동       2339.0  0.070448       10.0         5.0    50.000000
# 423  강동구    길동       3349.0  0.074369       17.0         6.0    35.294118
# 424  강동구  상일1동       7884.0  0.201967       13.0         8.0    61.538462
# 425  강동구  상일2동       1525.0  0.128345       15.0         7.0    46.666667
# 426  강동구   상일동          NaN       NaN        NaN         NaN          NaN
#
#      전체 유치원 수  국공립 유치원 수  국공립 유치원 비율  ...    외국인  외국인 비율  5대 범죄 발생 수  \
# ...

# %%
df21 = pd.read_csv('/Users/Jenny/Desktop/seoulbigcam/Final Data/주간인구지수_구별 2020.csv')

# %%
df21.rename(columns={'자치구별': '구'}, inplace=True)
df21 = df21[df21['구'] != '소계']

# %%
main21 = pd.merge(main20, df21, on = '구', how = 'left')
main21
# Out:
#        구     동  14세 이하 아동 수   ~14세 비율  전체 어린이집 수  국공립 어린이집 수  국공립 어린이집 비율  \
# 0    종로구   사직동        848.0  0.093320       11.0         1.0     9.090909
# 1    종로구   삼청동        142.0  0.060918        3.0         1.0    33.333333
# 2    종로구   부암동        709.0  0.076723        3.0         2.0    66.666667
# 3    종로구   평창동       1743.0  0.098681        3.0         1.0    33.333333
# 4    종로구   무악동        931.0  0.116041        3.0         3.0   100.000000
# ..   ...   ...          ...       ...        ...         ...          ...
# 422  강동구  천호2동       2339.0  0.070448       10.0         5.0    50.000000
# 423  강동구    길동       3349.0  0.074369       17.0         6.0    35.294118
# 424  강동구  상일1동       7884.0  0.201967       13.0         8.0    61.538462
# 425  강동구  상일2동       1525.0  0.128345       15.0         7.0    46.666667
# 426  강동구   상일동          NaN       NaN        NaN         NaN          NaN
#
#      전체 유치원 수  국공립 유치원 수  국공립 유치원 비율  ...  외국인 비율  5대 범죄 발생 수  경찰서 및 지구대(구)  \
# ...

# %%
df22 = pd.read_csv('/Users/Jenny/Desktop/seoulbigcam/Final Data/주택보급률_22년도 동별.csv')

# %%
df22.rename(columns={'구별': '구','동별': '동'}, inplace=True)
df22 = df22[df22['동'] != '소계']
df22['동'] = df22['동'].str.replace('일원2동', '개포3동')

# %%
main22 = pd.merge(main21, df22, on = ['구', '동'], how = 'outer')
main22
# Out:
#        구     동  14세 이하 아동 수   ~14세 비율  전체 어린이집 수  국공립 어린이집 수  국공립 어린이집 비율  \
# 0    종로구   사직동        848.0  0.093320       11.0         1.0     9.090909
# 1    종로구   삼청동        142.0  0.060918        3.0         1.0    33.333333
# 2    종로구   부암동        709.0  0.076723        3.0         2.0    66.666667
# 3    종로구   평창동       1743.0  0.098681        3.0         1.0    33.333333
# 4    종로구   무악동        931.0  0.116041        3.0         3.0   100.000000
# ..   ...   ...          ...       ...        ...         ...          ...
# 422  강동구  천호2동       2339.0  0.070448       10.0         5.0    50.000000
# 423  강동구    길동       3349.0  0.074369       17.0         6.0    35.294118
# 424  강동구  상일1동       7884.0  0.201967       13.0         8.0    61.538462
# 425  강동구  상일2동       1525.0  0.128345       15.0         7.0    46.666667
# 426  강동구   상일동          NaN       NaN        NaN         NaN          NaN
#
#      전체 유치원 수  국공립 유치원 수  국공립 유치원 비율  ...  경찰서 1개당 면적(구)  cctv 수(구)  \
# ...

# %%
df23 = pd.read_csv('/Users/Jenny/Desktop/seoulbigcam/Final Data/주택종류별_2020동별.csv')

# %%
df23 = df23.rename(columns={'구별': '구', '동별': '동', '총합': '주택종류별 총합'})
df23 = df23[df23['동'] != '소계']
df23['동'] = df23['동'].str.replace('일원2동', '개포3동')
df23
# Out:
#        구     동  주택종류별 총합 단독주택합 일반단독주택 다가구주택 영업겸용주택   아파트  연립주택 다세대 주택  \
# 2    종로구   사직동      2778   650    467   108     75  1591    78    411
# 3    종로구   삼청동       730   644    414   134     96     0    19     37
# 4    종로구   부암동      3070  1033    750   214     69   121   903    976
# 5    종로구   평창동      5958  1553   1088   314    151  1009  2186   1139
# 6    종로구   무악동      2860    48     14     9     25  2703    55     46
# ..   ...   ...       ...   ...    ...   ...    ...   ...   ...    ...
# 446  강동구  둔촌1동         5     5      X     X      X     0     X      X
# 447  강동구  둔촌2동      7962   543     31   377    135  5011   154   2187
# 448  강동구  암사1동     10089  1139     20   889    230  2790   247   5829
# 449  강동구  천호2동      9362  1488    103  1134    251  2641   189   4901
# 450  강동구    길동     14776   830     16   590    224  8719   588   4492
#
#     비거주용건물내주택  아파트/총합
# 2          48    0.57
# 3          30    0.00
# 4          37    0.04
# 5          71    0.17
# ...

# %%
main23 = pd.merge(main22, df23, on = ['구', '동'], how = 'outer')
main23
# Out:
#        구     동  14세 이하 아동 수   ~14세 비율  전체 어린이집 수  국공립 어린이집 수  국공립 어린이집 비율  \
# 0    종로구   사직동        848.0  0.093320       11.0         1.0     9.090909
# 1    종로구   삼청동        142.0  0.060918        3.0         1.0    33.333333
# 2    종로구   부암동        709.0  0.076723        3.0         2.0    66.666667
# 3    종로구   평창동       1743.0  0.098681        3.0         1.0    33.333333
# 4    종로구   무악동        931.0  0.116041        3.0         3.0   100.000000
# ..   ...   ...          ...       ...        ...         ...          ...
# 422  강동구  천호2동       2339.0  0.070448       10.0         5.0    50.000000
# 423  강동구    길동       3349.0  0.074369       17.0         6.0    35.294118
# 424  강동구  상일1동       7884.0  0.201967       13.0         8.0    61.538462
# 425  강동구  상일2동       1525.0  0.128345       15.0         7.0    46.666667
# 426  강동구   상일동          NaN       NaN        NaN         NaN          NaN
#
#      전체 유치원 수  국공립 유치원 수  국공립 유치원 비율  ...  주택종류별 총합  단독주택합  일반단독주택  다가구주택  \
# ...

# %%
df24 = pd.read_csv('/Users/Jenny/Desktop/seoulbigcam/Final Data/house_values.csv')
df25 = pd.read_csv('/Users/Jenny/Desktop/seoulbigcam/Final Data/land_values.csv')
df26 = pd.read_csv('/Users/Jenny/Desktop/seoulbigcam/Final Data/policy_proportion.csv')
df27 = pd.read_csv('/Users/Jenny/Desktop/seoulbigcam/Final Data/policy.csv')

# %%
sub = pd.merge(df24, df25, on = '법정동명', how = 'outer')
sub
# Out:
#       법정동명  mean_vlue/m**2  공시지가(원/㎡)
# 0      가락동     1231.790397    7228324
# 1     가리봉동      573.054163    3618488
# 2      가산동      802.271102    3283833
# 3      가양동     1114.016099    4120376
# 4      가회동     1533.384690    5830060
# ..     ...             ...        ...
# 460  충정로1가             NaN   10300134
# 461  태평로1가             NaN   23369596
# 462  태평로2가             NaN   25308682
# 463  회현동3가             NaN    9335876
# 464    훈정동             NaN    2811046
#
# [465 rows x 3 columns]

# %%
df26 = df26.drop(columns=['Unnamed: 0'],  axis=1)
df26 = df26.rename(columns={'구별': '구'})

# %%
main24 = pd.merge(main23, df26, on = '구', how = 'left')
main24
# Out:
#        구     동  14세 이하 아동 수   ~14세 비율  전체 어린이집 수  국공립 어린이집 수  국공립 어린이집 비율  \
# 0    종로구   사직동        848.0  0.093320       11.0         1.0     9.090909
# 1    종로구   삼청동        142.0  0.060918        3.0         1.0    33.333333
# 2    종로구   부암동        709.0  0.076723        3.0         2.0    66.666667
# 3    종로구   평창동       1743.0  0.098681        3.0         1.0    33.333333
# 4    종로구   무악동        931.0  0.116041        3.0         3.0   100.000000
# ..   ...   ...          ...       ...        ...         ...          ...
# 422  강동구  천호2동       2339.0  0.070448       10.0         5.0    50.000000
# 423  강동구    길동       3349.0  0.074369       17.0         6.0    35.294118
# 424  강동구  상일1동       7884.0  0.201967       13.0         8.0    61.538462
# 425  강동구  상일2동       1525.0  0.128345       15.0         7.0    46.666667
# 426  강동구   상일동          NaN       NaN        NaN         NaN          NaN
#
#      전체 유치원 수  국공립 유치원 수  국공립 유치원 비율  ...  18_집행액  19_예산액  19_집행액  20_예산액  \
# ...

# %%
main25 = pd.merge(main24, df27, on = '구', how = 'left')
main25
# Out:
#        구     동  14세 이하 아동 수   ~14세 비율  전체 어린이집 수  국공립 어린이집 수  국공립 어린이집 비율  \
# 0    종로구   사직동        848.0  0.093320       11.0         1.0     9.090909
# 1    종로구   삼청동        142.0  0.060918        3.0         1.0    33.333333
# 2    종로구   부암동        709.0  0.076723        3.0         2.0    66.666667
# 3    종로구   평창동       1743.0  0.098681        3.0         1.0    33.333333
# 4    종로구   무악동        931.0  0.116041        3.0         3.0   100.000000
# ..   ...   ...          ...       ...        ...         ...          ...
# 422  강동구  천호2동       2339.0  0.070448       10.0         5.0    50.000000
# 423  강동구    길동       3349.0  0.074369       17.0         6.0    35.294118
# 424  강동구  상일1동       7884.0  0.201967       13.0         8.0    61.538462
# 425  강동구  상일2동       1525.0  0.128345       15.0         7.0    46.666667
# 426  강동구   상일동          NaN       NaN        NaN         NaN          NaN
#
#      전체 유치원 수  국공립 유치원 수  국공립 유치원 비율  ...  16_예산액_y  16_집행액_y  17_예산액_y  \
# ...

# %%
df27 = df27.rename(columns={'구별': '구'})

# %%
main25.to_csv('main.csv')
sub.to_csv('sub.csv')

# %%
import pandas as pd

df = pd.read_csv('main_2차.csv')
df
# Out:
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
#        구     동  14세 이하 아동 수   ~14세 비율  전체 어린이집 수  국공립 어린이집 수  국공립 어린이집 비율  \
# 0    종로구   사직동        848.0  0.093320       11.0         1.0     9.090909
# 1    종로구   삼청동        142.0  0.060918        3.0         1.0    33.333333
# 2    종로구   부암동        709.0  0.076723        3.0         2.0    66.666667
# 3    종로구   평창동       1743.0  0.098681        3.0         1.0    33.333333
# 4    종로구   무악동        931.0  0.116041        3.0         3.0   100.000000
# ...

# %%
numeric_df = df.select_dtypes(include='number')
correlation_matrix = numeric_df.corr()
correlation_matrix
# Out:
#              14세 이하 아동 수   ~14세 비율  전체 어린이집 수  국공립 어린이집 수  국공립 어린이집 비율  \
# 14세 이하 아동 수     1.000000  0.759074   0.738496    0.664100    -0.023911
# ~14세 비율         0.759074  1.000000   0.425880    0.435268     0.041880
# 전체 어린이집 수       0.738496  0.425880   1.000000    0.762780    -0.146818
# 국공립 어린이집 수      0.664100  0.435268   0.762780    1.000000     0.363654
# 국공립 어린이집 비율    -0.023911  0.041880  -0.146818    0.363654     1.000000
# ...                  ...       ...        ...         ...          ...
# 18_집행액_y        0.225068  0.236718   0.083983    0.012413    -0.115323
# 19_예산액_y        0.255709  0.156376   0.191094    0.066624    -0.162269
# 19_집행액_y        0.209897  0.142770   0.124714    0.015608    -0.125384
# 20_예산액_y        0.189546  0.188562  -0.002315   -0.051505    -0.104384
# 20_집행액_y        0.165198  0.144595  -0.002808   -0.064053    -0.109574
#
#              전체 유치원 수  국공립 유치원 수  국공립 유치원 비율  어린이집 아동 수(구)  어린이집 교사 수(구)  ...  \
# ...

# %%
correlation_matrix.to_csv('상관관계.csv')
